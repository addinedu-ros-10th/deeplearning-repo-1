# %%
import cv2
from ultralytics import YOLO

model = YOLO("./runs/detect/json_ai_508_5items_sdj_v1.0/weights/best.pt")

cap = cv2.VideoCapture(0)

while cap.isOpened():

    ret, frame = cap.read()

    if not ret:
        break

    result = model(frame, conf = 0.6)

    image = list(result)[0].plot()

    cv2.imshow("test", image)

    key_input = cv2.waitKey(1)

    if key_input == ord('q') &0xff:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 47.2ms
# Speed: 1.8ms preprocess, 47.2ms inference, 33.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ...
